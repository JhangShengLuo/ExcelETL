# %%
def dirAndfileNameCheck():
    import os
    if not os.path.exists('process'):
        os.makedirs('process')
    with open('./process/nameCheck.txt','w') as nc:
        nc.write('檢查當下目錄'+os.getcwd()+'\n')
        print '檢查當下目錄',os.getcwd()
        nc.write('============'+'\n')
        print '============'
        files = []
        for k in os.listdir('.'):
            if os.path.isfile(k):
                files.append(k)
        countf = 0
        countnof = 0
        nc.write('正確格式'+'\n')
        print '正確格式' 
        for f in files:
            if'日報表' in f:
                countf += 1
                print f  #解開註解可以顯示檔案名稱
        nc.write('正確格式有'+str(countf)+'個'+'\n')
        print '正確格式有', countf,'個'
        nc.write('============'+'\n')
        print '============'
        nc.write('不正確格式'+'\n')
        print '不正確格式'        
        for f in files:  
            if('日報表' not in f)&( 'xls' in f):
                countnof += 1
                print f
        nc.write('不正確格式有'+str(countnof)+'個'+'\n')
        print '不正確格式有', countnof,'個'

# %%
dirAndfileNameCheck()
# Out:
# 檢查當下目錄 /Users/Jackie/Desktop/ETL/Final1004_04
# ============
# 正確格式
# 日報表105.04.11.xls
# 日報表105.04.12.xls
# 日報表105.04.13.xls
# 日報表105.04.14.xls
# 日報表105.04.15.xls
# 日報表105.04.18.xls
# 日報表105.04.19.xls
# 日報表105.04.20.xls
# 日報表105.04.21.xls
# 日報表105.04.22.xls
# 日報表105.04.25.xls
# 日報表105.04.26.xls
# 日報表105.04.28.xls
# 日報表105.05.05.xls
# 日報表105.05.06.xls
# 日報表105.05.09.xls
# 日報表105.05.10.xls
# 日報表105.05.11.xls
# 日報表105.05.12.xls
# 日報表105.05.13.xls
# 日報表105.05.16.xls
# 日報表105.05.17.xls
# 日報表105.05.18.xls
# 日報表105.05.19.xls
# 日報表105.05.20.xls
# 日報表105.05.23.xls
# 日報表105.05.24.xls
# 日報表105.05.25.xls
# 日報表105.05.26.xls
# 日報表105.05.27.xls
# 日報表105.05.28.xls
# 日報表105.05.29.xls
# 日報表105.05.30.xls
# 日報表105.05.31.xls
# 日報表105.06.01.xls
# 日報表105.06.02.xls
# 日報表105.06.03.xls
# 日報表105.06.04.xls
# 日報表105.06.05.xls
# 日報表105.06.06.xls
# 日報表105.06.07.xls
# 日報表105.06.10.xls
# 日報表105.06.11.xls
# 日報表105.06.12.xls
# 日報表105.06.13.xls
# 日報表105.06.14.xls
# 日報表105.06.15.xls
# 日報表105.06.16.xls
# 日報表105.06.17.xls
# 日報表105.06.18.xls
# 日報表105.06.19.xls
# 日報表105.06.20.xls
# 日報表105.06.21.xls
# 日報表105.06.22.xls
# 日報表105.06.23.xls
# 日報表105.06.24.xls
# 日報表105.06.25.xls
# 日報表105.06.26.xls
# 日報表105.06.27.xls
# 日報表105.06.28.xls
# 日報表105.06.29.xls
# 日報表105.06.30.xls
# 正確格式有 62 個
# ============
# 不正確格式
# 不正確格式有 0 個

# %%
# ---------設定字的格式
def set_style(name,height,bold=False):
    import xlwt
    style = xlwt.XFStyle() # 初始化样式
    font = xlwt.Font() # 为样式创建字体                    
    font.name = name # 'Times New Roman'
    font.bold = bold
    font.color_index = 4
    font.height = height
    # borders= xlwt.Borders()
    # borders.left= 6
    # borders.right= 6
    # borders.top= 6
    # borders.bottom= 6
    style.font = font  # style.borders = borders
    return style
# ---------

# %%
# -*- coding: utf8 -*-
#讀取北市Excel資料只抓出我所設定之內湖區的街道資料

import os
import shutil
if not os.path.exists('error'):
    os.makedirs('error')
try:
    if not os.path.exists('NeiHu'):
        os.makedirs('NeiHu')
except:
    print 'can not make NeiHu directory'
files = []
for f in os.listdir('.'):
        if os.path.isfile(f):
                files.append(f)
for f in files:
    if '日報表' in f:
        import xlrd,xlwt
        wbk = xlwt.Workbook()
        data = xlrd.open_workbook(f)
        sheet = wbk.add_sheet('sheet1',cell_overwrite_ok=True)
        table = data.sheet_by_name(u'詳表')  #以名字去找表1003改
        j=0
        for i in range(775,781):
            rows = table.row_values(i)
            j+=1
            for ele in range(0,len(rows)):
                sheet.write(j-1,ele,rows[ele],set_style('Times News Roman',200,True))
        #先從大範圍找，如果成功就繼續(1306)，失敗就用小一點的範圍(1303)，不再這兩個範圍就是資料缺失。
        a = range(1252,1306)
        b = range(1252,1303)
        try:
            for k in a :
                rows = table.row_values(k)
                print rows[2]
                if rows[2] == u'健康路-南京東路':
                    continue
                else:
                    j+=1
                    for ele in range(0,len(rows)):
                        sheet.write(j-1,ele,rows[ele],set_style('Times News Roman',200,True))
        except (IndexError):
            try:
                for k in b :
                    rows = table.row_values(k)
                    if rows[2] == u'健康路-南京東路':
                        continue
                    else:
                        j+=1
                        for ele in range(0,len(rows)):
                            sheet.write(j-1,ele,rows[ele],set_style('Times News Roman',200,True))
            except:
                print f,'list out of range'
#                     shutil.move(f,'error/'+f)
                continue


        # print len(rows)
        # for ele in rows:
        #     print ele
        # sheet.write(0,1,table)
        wbk.save('NeiHu/'+f)
# Out:
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 堤頂大道
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# 舊宗路
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-2371150d8c07> in <module>()
#      19         import xlrd,xlwt
#      20         wbk = xlwt.Workbook()
# ---> 21         data = xlrd.open_workbook(f)
#      22         sheet = wbk.add_sheet('sheet1',cell_overwrite_ok=True)
#      23         table = data.sheet_by_name(u'詳表')  #以名字去找表1003改
#
# /Users/Jackie/anaconda/lib/python2.7/site-packages/xlrd/__init__.pyc in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     439         formatting_info=formatting_info,
#     440         on_demand=on_demand,
# --> 441         ragged_rows=ragged_rows,
#     442         )
#     443     return bk
#
# /Users/Jackie/anaconda/lib/python2.7/site-packages/xlrd/book.pyc in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     117             bk._sheet_list = [None for sh in bk._sheet_names]
#     118             if not on_demand:
# --> 119                 bk.get_sheets()
#     120         bk.nsheets = len(bk._sheet_list)
#     121         if biff_version == 45 and bk.nsheets > 1:
#
# /Users/Jackie/anaconda/lib/python2.7/site-packages/xlrd/book.pyc in get_sheets(self)
#     676         for sheetno in xrange(len(self._sheet_names)):
#     677             if DEBUG: print("GET_SHEETS: sheetno =", sheetno, self._sheet_names, self._sh_abs_posn, file=self.logfile)
# --> 678             self.get_sheet(sheetno)
#     679
#     680     def fake_globals_get_sheet(self): # for BIFF 4.0 and earlier
#
# /Users/Jackie/anaconda/lib/python2.7/site-packages/xlrd/book.pyc in get_sheet(self, sh_number, update_pos)
#     667                 sh_number,
#     668                 )
# --> 669         sh.read(self)
#     670         self._sheet_list[sh_number] = sh
#     671         return sh
#
# /Users/Jackie/anaconda/lib/python2.7/site-packages/xlrd/sheet.pyc in read(self, bk)
#     794                 rowx, colx, xf_index, sstindex = local_unpack('<HHHi', data)
#     795                 # print "LABELSST", rowx, colx, sstindex, bk._sharedstrings[sstindex]
# --> 796                 self_put_cell(rowx, colx, XL_CELL_TEXT, bk._sharedstrings[sstindex], xf_index)
#     797                 if do_sst_rich_text:
#     798                     runlist = bk._rich_text_runlist_map.get(sstindex)
#
# /Users/Jackie/anaconda/lib/python2.7/site-packages/xlrd/sheet.pyc in put_cell_unragged(self, rowx, colx, ctype, value, xf_index)
#     693             # self.extend_cells(rowx+1, colx+1)
#     694             # self._put_cell_exceptions += 1
# --> 695             nr = rowx + 1
#     696             nc = colx + 1
#     697             assert 1 <= nc <= self.utter_max_cols
#
# KeyboardInterrupt:

# %%
# -*- coding: utf8 -*-
#讀取北市Excel資料只抓出我所設定之內湖區的街道資料
def julToSepNeihu():
    import os
    import shutil
    if not os.path.exists('error'):
        os.makedirs('error')
    try:
        if not os.path.exists('NeiHu'):
            os.makedirs('NeiHu')
    except:
        print 'can not make NeiHu directory'
    files = []
    for f in os.listdir('.'):
            if os.path.isfile(f):
                    files.append(f)
    for f in files:
        if '日報表' in f:
            import xlrd,xlwt
            wbk = xlwt.Workbook()
            data = xlrd.open_workbook(f)
            sheet = wbk.add_sheet('sheet1',cell_overwrite_ok=True)
            table = data.sheet_by_name(u'詳表')  #以名字去找表1003改
            j=0
            for i in range(775,781):
                rows = table.row_values(i)
                j+=1
                for ele in range(0,len(rows)):
                    sheet.write(j-1,ele,rows[ele],set_style('Times News Roman',200,True))
            #先從大範圍找，如果成功就繼續(1306)，失敗就用小一點的範圍(1303)，不再這兩個範圍就是資料缺失。
            a = range(1252,1306)
            b = range(1252,1303)
            try:
                for k in a :
                    rows = table.row_values(k)
                    if rows[2] == u'健康路-南京東路':
                        continue
                    else:
                        j+=1
                        
                        for ele in range(0,len(rows)):
                            sheet.write(j-1,ele,rows[ele],set_style('Times News Roman',200,True))
            except (IndexError):
                try:
                    for k in b :
                        rows = table.row_values(k)
                        if rows[2] == u'健康路-南京東路':
                            continue
                        else:
                            j+=1
                            #             4到6月多了比對欄index:0，都順延一個寫入
                            for ele in range(1,len(rows)):
                                sheet.write(j-1,ele-1,rows[ele],set_style('Times News Roman',200,True))
                except:
                    print f,'list out of range'
                    shutil.move(f,'error/'+f)
                    continue
                    

            # print len(rows)
            # for ele in rows:
            #     print ele
            # sheet.write(0,1,table)
            wbk.save('NeiHu/'+f)

# %%
julToSepNeihu()
# Out:
# 日報表105.05.28.xls list out of range
# 日報表105.05.29.xls list out of range
# 日報表105.06.04.xls list out of range
# 日報表105.06.05.xls list out of range
# 日報表105.06.11.xls list out of range
# 日報表105.06.12.xls list out of range
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
import os
files = []
for f in os.listdir('./NeiHu'):      
    files.append(f)
for f in files:
    print f
# Out:
# .DS_Store
# 日報表105.04.11.xls
# 日報表105.04.12.xls
# 日報表105.04.13.xls
# 日報表105.04.14.xls
# 日報表105.04.15.xls
# 日報表105.04.18.xls
# 日報表105.04.19.xls
# 日報表105.04.20.xls
# 日報表105.04.21.xls
# 日報表105.04.22.xls
# 日報表105.04.25.xls
# 日報表105.04.26.xls
# 日報表105.04.28.xls
# 日報表105.05.05.xls
# 日報表105.05.06.xls
# 日報表105.05.09.xls
# 日報表105.05.10.xls
# 日報表105.05.11.xls
# 日報表105.05.12.xls
# 日報表105.05.13.xls
# 日報表105.05.16.xls
# 日報表105.05.17.xls
# 日報表105.05.18.xls
# 日報表105.05.19.xls
# 日報表105.05.20.xls
# 日報表105.05.23.xls
# 日報表105.05.24.xls
# 日報表105.05.25.xls
# 日報表105.05.26.xls
# 日報表105.05.27.xls
# 日報表105.05.30.xls
# 日報表105.05.31.xls
# 日報表105.06.01.xls
# 日報表105.06.02.xls
# 日報表105.06.03.xls
# 日報表105.06.06.xls
# 日報表105.06.07.xls
# 日報表105.06.10.xls
# 日報表105.06.13.xls
# 日報表105.06.14.xls
# 日報表105.06.15.xls
# 日報表105.06.16.xls
# 日報表105.06.17.xls
# 日報表105.06.18.xls
# 日報表105.06.19.xls
# 日報表105.06.20.xls
# 日報表105.06.21.xls
# 日報表105.06.22.xls
# 日報表105.06.23.xls
# 日報表105.06.24.xls
# 日報表105.06.25.xls
# 日報表105.06.26.xls
# 日報表105.06.27.xls
# 日報表105.06.28.xls
# 日報表105.06.29.xls
# 日報表105.06.30.xls

# %%
#讀取內湖資料只抓出設定之內湖區各時段分開的街道資料，將三個時段資料存成三個資料夾（上/下/全日）。
# -*- coding: utf-8 -*-
def writePeriod09():
    import os
    if not os.path.exists('NeiHu/上午時段'):
        os.makedirs('NeiHu/上午時段')
    if not os.path.exists('NeiHu/下午時段'):
        os.makedirs('NeiHu/下午時段')
    if not os.path.exists('NeiHu/全日時段'):
        os.makedirs('NeiHu/全日時段')
    
#      上午時段
    files = []
    for f in os.listdir('./NeiHu'):      
        files.append(f)
    for f in files:
        if '日報表' in f:
            import xlrd,xlwt
            wbk = xlwt.Workbook()
            data = xlrd.open_workbook('NeiHu/'+f)
            sheet = wbk.add_sheet('sheet1',cell_overwrite_ok=True)
            table = data.sheets()[0]
            j=0
            for i in range(0,57,+3):#只取上午時段
                rows = table.row_values(i)
                j+=1
                for ele in range(0,len(rows)):
                    sheet.write(j-1,ele,rows[ele],set_style('Times News Romans',200,True))
            sheet.write(j,5,"=SUM(F1:F19)")
            # print len(rows)
            # for ele in rows:
            #     print ele
            # sheet.write(0,1,table)
            wbk.save('NeiHu/上午時段/'+'上午'+f)
#     下午時段        
    files = []
    for f in os.listdir('./NeiHu'):
            
        files.append(f)
    for f in files:
        if '日報表' in f:
            import xlrd,xlwt
            wbk = xlwt.Workbook()
            data = xlrd.open_workbook('NeiHu/'+f)
            sheet = wbk.add_sheet('sheet1',cell_overwrite_ok=True)
            table = data.sheets()[0]
            j=0
            for i in range(1,57,+3):#只取下午時段
                rows = table.row_values(i)
                j+=1
                for ele in range(0,len(rows)):
                    sheet.write(j-1,ele,rows[ele],set_style('Times News Romans',200,True))
            sheet.write(j,5,"=SUM(F1:F19)")
            # print len(rows)
            # for ele in rows:
            #     print ele
            # sheet.write(0,1,table)
            wbk.save('NeiHu/下午時段/'+'下午'+f)
#      全日時段        
    files = []
    for f in os.listdir('./NeiHu'):
            
        files.append(f)
    for f in files:
        if '日報表' in f:
            import xlrd,xlwt
            wbk = xlwt.Workbook()
            data = xlrd.open_workbook('NeiHu/'+f)
            sheet = wbk.add_sheet('sheet1',cell_overwrite_ok=True)
            table = data.sheets()[0]
            j=0
            for i in range(2,57,+3):#只取全日時段

                rows = table.row_values(i)
                j+=1
                for ele in range(0,len(rows)):
                    sheet.write(j-1,ele,rows[ele],set_style('Times News Romans',200,True))
            sheet.write(j,5,"=SUM(F1:F19)")
            # print len(rows)
            # for ele in rows:
            #     print ele
            # sheet.write(0,1,table)
            wbk.save('NeiHu/全日時段/'+'全日'+f)

# %%
writePeriod09()

# %%
#  把抓出來的內湖區的資料，取檔案日期跟當日所有路段的當量做總和，在寫成一個csv檔

def periodVolume09():
    # -*- coding: utf-8 -*-
    import os,re
    import csv
#     上午
    try:
        newcsv = open('NeiHu/上午時段/上午.csv','w')
        files = []
        for f in os.listdir('./NeiHu/上午時段'):
            files.append(f)
        #  在表頭加上分類    
        newcsv.write('date'+','+'eq'+','+'day'+'\n')
        for f in files:
            if '日報表' in f:
                import xlrd
                
                data = xlrd.open_workbook('NeiHu/上午時段/'+f)
                table = data.sheets()[0]
                cols = table.col_values(5)
#                 7to9的星期是row(0)[12],但是4to6在row(0)[9]的地方 
                cellDay = table.row(0)[9].value
                sumall = 0
                for i in range(0,len(cols)-1):
                #print cols[i]
                    sumall += float(cols[i])
                match = re.findall('[0-9]+.[0-9]+.[0-9]+',f)
    #             print str(match[0]) , str(sumall) # 解開註解可以印出來看 
                newcsv.write(str(match[0])+','+str(sumall)+','+str(cellDay)+'\n')
        newcsv.close()
        
    except:
        print 'no 上午時段 directory'
    try:

    #     下午
        newcsv = open('NeiHu/下午時段/下午.csv','w')
        files = []
        for f in os.listdir('./NeiHu/下午時段'):
            files.append(f)
            #  在表頭加上分類    
        newcsv.write('date'+','+'eq'+','+'day'+'\n')
        for f in files:
            if '日報表' in f:
                import xlrd
               
                data = xlrd.open_workbook('NeiHu/下午時段/'+f)
                table = data.sheets()[0]
                cols = table.col_values(5)
                #                 7to9的星期是row(0)[12],但是4to6在row(0)[9]的地方 
                cellDay = table.row(0)[9].value
                sumall = 0
                for i in range(0,len(cols)-1):
                #print cols[i]
                    sumall += float(cols[i])
                match = re.findall('[0-9]+.[0-9]+.[0-9]+',f)
    #             print str(match[0]) , str(sumall) # 解開註解可以印出來看 
                newcsv.write(str(match[0])+','+str(sumall)+','+str(cellDay)+'\n')
        newcsv.close()
    except:
        print 'no 下午時段 directory'
    try:

    #     全日

        newcsv = open('NeiHu/全日時段/全日.csv','w')
        files = []
        for f in os.listdir('./NeiHu/全日時段'):
            files.append(f)
            #  在表頭加上分類    
        newcsv.write('date'+','+'eq'+','+'day'+'\n')
        for f in files:
            if '日報表' in f:
                import xlrd
              
                data = xlrd.open_workbook('NeiHu/全日時段/'+f)
                table = data.sheets()[0]
                cols = table.col_values(5)
                #                 7to9的星期是row(0)[12],但是4to6在row(0)[9]的地方 
                cellDay = table.row(0)[9].value
                sumall = 0
                for i in range(0,len(cols)-1):
                #print cols[i]
                    sumall += float(cols[i])
                match = re.findall('[0-9]+.[0-9]+.[0-9]+',f)
    #             print str(match[0]) , str(sumall) # 解開註解可以印出來看 
#     加上了星期幾str(cellDay)
                newcsv.write(str(match[0])+','+str(sumall)+','+str(cellDay)+'\n')
        newcsv.close()
        
    except:
        print 'no 全日時段 directory'

# %%
periodVolume09()
# Out:
# no 上午時段 directory
# no 下午時段 directory
# no 全日時段 directory

# %%
# 把上下午合併，目前用不到

# def morningAndNoon():

#     import os
#     import csv
#     if not os.path.exists('NeiHu/上下午'):
#         os.makedirs('NeiHu/上下午')

#     morning = open('NeiHu/上午時段/上午.csv','rU')
#     noon = open('NeiHu/下午時段/下午.csv','rU')
#     twoPeriod = open('NeiHu/上下午/上下午.csv','w')

#     # 上午
#     mrlist = []
#     mr = csv.reader(morning,delimiter=' ')
#     for mrow in mr:
#         mrlist.append(mrow)


#     # 下午
#     nrlist = []
#     nr = csv.reader(noon,delimiter=' ')
#     for nrow in nr:
#         nrlist.append(nrow)

#     # print len(nrlist)


#     for i in range(0,len(mrlist)):
#     #     print nrlist[i][0]
#         twoPeriod.write(mrlist[i][0]+','+'am')
#         twoPeriod.write('\n')

#         twoPeriod.write(nrlist[i][0]+','+'pm')
#         twoPeriod.write('\n')



#     morning.close()
#     noon.close()
#     twoPeriod.close()

# %%
# morningAndNoon()
